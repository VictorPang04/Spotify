# %%
# Dependencies and Setup
import pandas as pd
#import demoji
import matplotlib.pyplot as plt
#import matplotlib_venn as venn

# File to Load
chart_path = "../spotify_charts.csv"

# Read Chart Data File and store into Pandas DataFrames
chart_data = pd.read_csv(chart_path, encoding='utf-8')

# %%
#remove global from the regions column
regional_df = chart_data[chart_data["region"] != "Global"]

# %%
#count countries
len(regional_df['region'].unique())
# Out:
# 68

# %%
#create new df based on region
top_countries = regional_df.groupby(['region'])[['total streams','artist']].sum()

#sort df to find top streaming countries
sorted_countries = top_countries.sort_values('total streams', ascending = False)

#variable for top ten countries
top_ten = sorted_countries.head(10)

#variable for bottom ten countries
bottom_ten = sorted_countries.tail(10)

# %%
#create bar plot to show all countries streams 

sorted_countries_plot = sorted_countries.plot.bar(y='total streams', figsize =(30,30), width=.5, alpha=1, align="center")

#adds title to bar chart  
plt.title("Countries Ranked By Streaming")

#label xaxis
plt.xlabel("Countries")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()

# %%
#create bar plot to show top 10 countries streams 
top_countries_plot = top_ten.plot.bar(y='total streams', figsize=(5, 5), width=.5, alpha=1, align="center")

#add title
plt.title("Top Ten Countries By Streaming")

#label xaxis
plt.xlabel("Countries")

#lable yaxis
plt.ylabel("Streams (in billions)")

#adjust graph layout 
plt.tight_layout()

#show graph 
plt.show()

# %%
#Top artists for each of the top ten countries by year

# %%
df_2017 = chart_data[(chart_data["region"] == "Global") & (chart_data["date"] == 2017)]

artists_2017 = df_2017.sort_values('total streams', ascending = False)

artists_2017.head(10)

top_artists_2017 = artists_2017.head(10)
top_artists_2017
# Out:
#        date                                              title  \
# 48188  2017                                       Shape of You
# 12958  2017                                  Despacito - Remix
# 12901  2017                 Despacito (Featuring Daddy Yankee)
# 50763  2017                           Something Just Like This
# 20887  2017                                            HUMBLE.
# 58415  2017                                      Unforgettable
# 26931  2017                    It Ain't Me (with Selena Gomez)
# 64176  2017                                           rockstar
# 54451  2017                                 That's What I Like
# 24551  2017  I Don’t Wanna Live Forever (Fifty Shades Darke...
#
#                                         artist  region  total streams
# 48188                               Ed Sheeran  Global   1.479857e+09
# 12958  Luis Fonsi, Daddy Yankee, Justin Bieber  Global   9.085726e+08
# ...

# %%
df_2018 = chart_data[(chart_data["region"] == "Global") & (chart_data["date"] == 2018)]

artists_2018 = df_2018.sort_values('total streams', ascending = False)

artists_2018.head(10)

top_artists_2018 = artists_2018.head(10)
top_artists_2018
# Out:
#         date                         title                        artist  \
# 91525   2018                    God's Plan                         Drake
# 122797  2018                          SAD!                  XXXTENTACION
# 119406  2018  Psycho (feat. Ty Dolla $ign)                   Post Malone
# 98407   2018                In My Feelings                         Drake
# 74624   2018                    Better Now                   Post Malone
# 96345   2018                     I Like It  Cardi B, Bad Bunny, J Balvin
# 115511  2018      One Kiss (with Dua Lipa)                 Calvin Harris
# 97670   2018                         IDGAF                      Dua Lipa
# 106500  2018                  Lucid Dreams                    Juice WRLD
# 87575   2018                       FRIENDS        Marshmello, Anne-Marie
#
#         region  total streams
# 91525   Global   1.126032e+09
# 122797  Global   7.640701e+08
# 119406  Global   7.023187e+08
# 98407   Global   7.021119e+08
# ...

# %%
df_2019 = chart_data[(chart_data["region"] == "Global") & (chart_data["date"] == 2019)]

artists_2019 = df_2019.sort_values('total streams', ascending = False)

artists_2019.head(10)

top_artists_2019 = artists_2019.head(10)
top_artists_2019
# Out:
#         date                                          title  \
# 206911  2019                                       Señorita
# 222870  2019                                        bad guy
# 211012  2019  Sunflower - Spider-Man: Into the Spider-Verse
# 150418  2019                                        7 rings
# 209271  2019                              Someone You Loved
# 177812  2019              I Don't Care (with Justin Bieber)
# 163502  2019                                   Dance Monkey
# 221201  2019                                           Wow.
# 161803  2019                                      Con Calma
# 207040  2019                                        Shallow
#
#                               artist  region  total streams
# 206911  Shawn Mendes, Camila Cabello  Global   1.070268e+09
# 222870                 Billie Eilish  Global   1.052359e+09
# 211012         Post Malone, Swae Lee  Global   9.869068e+08
# 150418                 Ariana Grande  Global   9.613615e+08
# ...

# %%
df_2020 = chart_data[(chart_data["region"] == "Global") & (chart_data["date"] == 2020)]

artists_2020 = df_2020.sort_values('total streams', ascending = False)

artists_2020.head(10)

top_artists_2020 = artists_2020.head(10)
top_artists_2020
# Out:
#         date                             title                artist  region  \
# 237896  2020                   Blinding Lights            The Weeknd  Global
# 244984  2020                      Dance Monkey           Tones And I  Global
# 289202  2020             Roses - Imanbek Remix             SAINt JHN  Global
# 300515  2020                           The Box           Roddy Ricch  Global
# 247554  2020                   Don't Start Now              Dua Lipa  Global
# 286944  2020      ROCKSTAR (feat. Roddy Ricch)                DaBaby  Global
# 307046  2020                  Watermelon Sugar          Harry Styles  Global
# 295471  2020                 Someone You Loved         Lewis Capaldi  Global
# 311637  2020  death bed (coffee for your head)    Powfu, beabadoobee  Global
# 303712  2020                              Tusa  KAROL G, Nicki Minaj  Global
#
#         total streams
# 237896   1.645923e+09
# 244984   1.196398e+09
# 289202   1.040359e+09
# 300515   1.036463e+09
# ...

# %%
df_2021 = chart_data[(chart_data["region"] == "Global") & (chart_data["date"] == 2021)]

artists_2021 = df_2021.sort_values('total streams', ascending = False)

artists_2021.head(10)

top_artists_2021 = artists_2021.head(10)
top_artists_2021
# Out:
#         date                                   title          artist  region  \
# 396913  2021                         drivers license  Olivia Rodrigo  Global
# 377424  2021               STAY (with Justin Bieber)   The Kid LAROI  Global
# 360698  2021          MONTERO (Call Me By Your Name)       Lil Nas X  Global
# 397403  2021                                good 4 u  Olivia Rodrigo  Global
# 357373  2021               Levitating (feat. DaBaby)        Dua Lipa  Global
# 371353  2021  Peaches (feat. Daniel Caesar & Giveon)   Justin Bieber  Global
# 354077  2021                Kiss Me More (feat. SZA)        Doja Cat  Global
# 328392  2021                         Blinding Lights      The Weeknd  Global
# 347305  2021                              Heat Waves   Glass Animals  Global
# 350399  2021       INDUSTRY BABY (feat. Jack Harlow)       Lil Nas X  Global
#
#         total streams
# 396913   1.166101e+09
# 377424   1.165565e+09
# 360698   1.129255e+09
# 397403   1.099668e+09
# ...

# %%
artist_streams = df_2017.groupby(["artist"]).max()["total streams"]
artist_streams

#min_timepoint = clean_data.groupby("Timepoint")["Tumor Volume (mm3)"].min().reset_index()
# Out:
# artist
# *NSYNC                                                      2985809.0
# 187 Strassenbande, Bonez MC, Gzuz                           3378952.0
# 187 Strassenbande, Bonez MC, RAF Camora, Gzuz, Maxwell       427921.0
# 187 Strassenbande, Gzuz, Bonez MC, LX                        431433.0
# 2 Chainz, Gucci Mane, Quavo                                 2286889.0
#                                                              ...
# Zedd, Alessia Cara                                          2332992.0
# Zion & Lennox                                             242157471.0
# alt-J                                                        535620.0
# blackbear                                                  91504558.0
# gnash                                                      68354550.0
# Name: total streams, Length: 642, dtype: float64

# %%
#work on genre using dataframe created by year

# %%
BL_df = chart_data[(chart_data["region"] != "Global") & 
                   (chart_data["title"] == "Blinding Lights")]

# %%
BL_sorted = BL_df.sort_values("total streams", ascending = False)
BL_sorted
# Out:
#         date            title      artist          region  total streams
# 237940  2020  Blinding Lights  The Weeknd   United States    331037132.0
# 328437  2021  Blinding Lights  The Weeknd   United States    177035940.0
# 237913  2020  Blinding Lights  The Weeknd          Mexico    144665106.0
# 237895  2020  Blinding Lights  The Weeknd         Germany    122234476.0
# 237939  2020  Blinding Lights  The Weeknd  United Kingdom    113847572.0
# ...      ...              ...         ...             ...            ...
# 237911  2020  Blinding Lights  The Weeknd      Luxembourg        61660.0
# 157337  2019  Blinding Lights  The Weeknd            Peru        43652.0
# 328407  2021  Blinding Lights  The Weeknd      Luxembourg        32115.0
# 157328  2019  Blinding Lights  The Weeknd      Luxembourg        13435.0
# 157334  2019  Blinding Lights  The Weeknd       Nicaragua         1026.0
#
# [197 rows x 5 columns]

# %%
#song_sum = BL_sorted["total streams"].groupby(artist["artist"]).sum()
artist_sum = regional_df[(artists_expanded_df["region"] != "Global")]
artist_sum = artist.groupby('artist')['total streams'].sum()
song_sum
# Out:
# 2559543032.0

# %%
artists_expanded_df = chart_data.assign(artist=chart_data.artist.str.split(',')).explode('artist')
artist = artists_expanded_df[(artists_expanded_df["region"] != "Global")]
artist_sum = artist.groupby('artist')['total streams'].sum()
sum_stat = pd.DataFrame({"Total streams":artist_sum})
non_global_sorted = sum_stat.sort_values("Total streams", ascending = False)

#non_global = non_global_sorted.head(20)
non_global_sorted
# Out:
#                           Total streams
# artist
# Post Malone                1.295997e+10
# Ed Sheeran                 1.052557e+10
# Drake                      1.013480e+10
# Bad Bunny                  9.430947e+09
# Billie Eilish              7.711924e+09
# ...                                 ...
# Dossey                     1.002000e+03
#  Viet                      1.002000e+03
# D-mol                      1.001000e+03
# Street Pound Productions   1.001000e+03
#  Lota                      1.001000e+03
#
# [36183 rows x 1 columns]

# %%
artists_expanded_df = chart_data.assign(artist=chart_data.artist.str.split(',')).explode('artist')
artist = artists_expanded_df[(artists_expanded_df["region"] != "Global") &
                            ((artists_expanded_df["artist"] == "Post Malone") | 
                             (artists_expanded_df["artist"] == "Ed Sheeran") | 
                             (artists_expanded_df["artist"] == "Drake") | 
                             (artists_expanded_df["artist"] == "Billie Eilish") | 
                             (artists_expanded_df["artist"] == "Bad Bunny") | 
                             (artists_expanded_df["artist"] == "Ariana Grande") | 
                             (artists_expanded_df["artist"] == "The Weeknd") | 
                             (artists_expanded_df["artist"] == "J Balvin") | 
                             (artists_expanded_df["artist"] == "XXXTENTACION") | 
                             (artists_expanded_df["artist"] == "Dua Lipa") | 
                            (artists_expanded_df["artist"] == "Juice WRLD"))]
artist_sum = artist.groupby('artist')['total streams'].sum()
sum_stat = pd.DataFrame({"Total streams":artist_sum})
non_global_sorted = sum_stat.sort_values("Total streams", ascending = False)

global_ten_artists = non_global_sorted.head(50)
global_ten_artists
# Out:
#                Total streams
# artist
# Post Malone     1.295997e+10
# Ed Sheeran      1.052557e+10
# Drake           1.013480e+10
# Bad Bunny       9.430947e+09
# Billie Eilish   7.711924e+09
# Ariana Grande   7.335166e+09
# The Weeknd      6.766955e+09
# Juice WRLD      6.542432e+09
# J Balvin        5.870434e+09
# Dua Lipa        5.842740e+09
# XXXTENTACION    5.776921e+09

# %%
#separating artists
artists_expanded_df = chart_data.assign(artist=chart_data.artist.str.split(',')).explode('artist')
# artist = artists_expanded_df[(artists_expanded_df["region"] == "!Global")]
# artist_sum = artist["total streams"].groupby(artist["artist"]).sum()
# sum_stat = pd.DataFrame({"Total streams":artist_sum})
# global_sorted = sum_stat.sort_values("Total streams", ascending = False)

# global_fifty = global_sorted.head(50)

# global_ten = global_sorted.head(10)
# global_ten
artists_expanded_df
# Out:
#         date                                      title          artist  \
# 0       2017  "All That Is or Ever Was or Ever Will Be"  Alan Silvestri
# 1       2017  "All That Is or Ever Was or Ever Will Be"  Alan Silvestri
# 2       2017               "Read All About It, Pt. III"     Emeli Sandé
# 3       2017               "Read All About It, Pt. III"     Emeli Sandé
# 4       2017               "Read All About It, Pt. III"     Emeli Sandé
# ...      ...                                        ...             ...
# 404949  2021                                   욱 (UGH!)             BTS
# 404950  2021                                         친구             BTS
# 404951  2021                                    키스는 다음에           LOONA
# 404952  2021                                          🪐        Coldplay
# 404953  2021                                          🪐        Coldplay
#
#                 region  total streams
# 0               Poland         3547.0
# ...

# %%
sorted_artist_plot = global_fifty.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, 
                                            align="center", color = "green")

#adds title to bar chart  
plt.title("Artists Ranked By Streaming")

#label xaxis
plt.xlabel("Artists")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 90)

#show graph 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24860\2635670701.py in <module>
# ----> 1 sorted_artist_plot = global_fifty.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1,
#       2                                             align="center", color = "green")
#       3
#       4 #adds title to bar chart
#       5 plt.title("Artists Ranked By Streaming")
#
# NameError: name 'global_fifty' is not defined

# %%
# artists_expanded_df = chart_data.assign(artist=chart_data.artist.str.split(',')).explode('artist')
# artist_df = artists_expanded_df[(artists_expanded_df["region"] != "Global")]
# artist_df

artists_expanded_df = chart_data.assign(artist=chart_data.artist.str.split(',')).explode('artist')
df_pang = artists_expanded_df[(artists_expanded_df["region"] != "Global")]
# df_pang = chart_data[(chart_data["region"] != "Global")]

artists_pang = df_pang.sort_values('total streams', ascending = False)

artist_sum = artists_pang["total streams"].groupby(artists_pang["artist"]).sum()
sum_stat = pd.DataFrame({"Total streams":artist_sum})
non_global_sorted = sum_stat.sort_values("Total streams", ascending = False)
non_global_sorted
non_global = non_global_sorted.head(10)
artists_pang

# artist_df.drop_duplicates(subset=['artist'], keep='last')
# artist_sum = artist_df["total streams"].groupby(artist_df["artist"]).sum()
# sum_stat = pd.DataFrame({"Total streams":artist_sum})
# non_global_sorted = sum_stat.sort_values("Total streams", ascending = False)

# non_global = non_global_sorted.head(50)
# non_global
# Out:
#         date                                          title  \
# 91563   2018                                     God's Plan
# 300559  2020                                        The Box
# 211054  2019  Sunflower - Spider-Man: Into the Spider-Verse
# 211054  2019  Sunflower - Spider-Man: Into the Spider-Verse
# 20921   2017                                        HUMBLE.
# ...      ...                                            ...
# 226497  2019                                      خالي بلاش
# 102569  2018                    La Guitarra - MTV Unplugged
# 206266  2019                            Scared to Be Lonely
# 206266  2019                            Scared to Be Lonely
# 284444  2020                                        Piccola
#
#                            artist                region  total streams
# 91563                       Drake         United States    453226629.0
# 300559                Roddy Ricch         United States    400892436.0
# ...

# %%
sorted_artist_plot = non_global.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, 
                                            align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Artists Ranked By Streaming")

#label xaxis
plt.xlabel("Artists")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 90)

#show graph 
plt.show()

# %%
# Top 30 Artists by streams
artists_expanded_df = chart_data.assign(artist=chart_data.artist.str.split(',')).explode('artist')
post_malone = artists_expanded_df[(artists_expanded_df["region"] != "Global")]
pm_sum = post_malone["total streams"].groupby(post_malone["artist"]).sum()
sum_stat = pd.DataFrame({"Total streams":pm_sum})
non_global_sorted = sum_stat.sort_values("Total streams", ascending = False)

non_global_sorted.head(30)
# Out:
#                   Total streams
# artist
# Post Malone        1.295997e+10
# Ed Sheeran         1.052557e+10
# Drake              1.013480e+10
# Bad Bunny          9.430947e+09
# Billie Eilish      7.711924e+09
#  J Balvin          7.615008e+09
# Ariana Grande      7.335166e+09
#  Bad Bunny         7.283861e+09
# The Weeknd         6.766955e+09
# Juice WRLD         6.542432e+09
# J Balvin           5.870434e+09
# Dua Lipa           5.842740e+09
# XXXTENTACION       5.776921e+09
#  Ozuna             4.985298e+09
# Travis Scott       4.557267e+09
# Olivia Rodrigo     4.493199e+09
# Justin Bieber      4.341090e+09
# Ozuna              4.215782e+09
# Lil Nas X          4.127712e+09
#  Daddy Yankee      4.116022e+09
# Shawn Mendes       4.026492e+09
# Taylor Swift       3.987928e+09
#  Anuel AA          3.962228e+09
#  Farruko           3.896187e+09
# Khalid             3.832042e+09
# Maluma             3.802868e+09
# The Chainsmokers   3.748871e+09
#  Myke Towers       3.651704e+09
# ...

# %%
# 9.430947e+09 + 7.283861e+09
# Bad Bunny = 16714808000.0
# 7.615008e+09 + 5.870434e+09
# J Balvin = 13485442000.0
# 4.985298e+09 + 4.215782e+09
# Ozuna = 9201080000.0

# If yes then Bad Bunny, J Balvin, Post, Ed Sheeran, Drake, Ozuna, Billie Eilish, Ariana, Weeknd, Juice WRLD
# If no then Post, Ed sheeran, Drake, Bad Bunny, Billie, J Balvin, Ariana, The Weeknd, Juice WRLD, DUA Lipa

# %%
us = chart_data[(chart_data["region"] == "United States") & (chart_data["artist"] == "Bad Bunny")]
us['total streams'].sum()
non_us_df = chart_data[(chart_data["region"] != "Global") & 
                       (chart_data["artist"] == "Bad Bunny")]
non_us_df['total streams'].sum()

#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United States'],
                          'Total Countries':countries_count})
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)
plt.show()

# %%
us = chart_data[(chart_data["region"] == "United States") & (chart_data["artist"] == "Post Malone")]
us['total streams'].sum()
non_us_df = chart_data[(chart_data["region"] != "Global") & 
                       (chart_data["artist"] == "Post Malone")]
non_us_df['total streams'].sum()

#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United States'],
                          'Total Countries':countries_count})
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)
plt.show()

# %%
us = chart_data[(chart_data["region"] == "United States") & (chart_data["artist"] == "Ed Sheeran")]
us['total streams'].sum()
non_us_df = chart_data[(chart_data["region"] != "Global") & 
                       (chart_data["artist"] == "Ed Sheeran")]
non_us_df['total streams'].sum()

#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United States'],
                          'Total Countries':countries_count})
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)
plt.show()

# %%
us = chart_data[(chart_data["region"] == "United States") & (chart_data["artist"] == "Drake")]
us['total streams'].sum()
non_us_df = chart_data[(chart_data["region"] != "Global") & 
                       (chart_data["artist"] == "Drake")]
non_us_df['total streams'].sum()

#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United States'],
                          'Total Countries':countries_count})
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)
plt.show()

# %%
us = chart_data[(chart_data["region"] == "United States") & (chart_data["artist"] == "Billie Eilish")]
us['total streams'].sum()
non_us_df = chart_data[(chart_data["region"] != "Global") & 
                       (chart_data["artist"] == "Billie Eilish")]
non_us_df['total streams'].sum()

#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United States'],
                          'Total Countries':countries_count})
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)
plt.show()

# %%
us = chart_data[(chart_data["region"] == "United States") & (chart_data["artist"] == "J Balvin")]
us['total streams'].sum()
non_us_df = chart_data[(chart_data["region"] != "Global") & 
                       (chart_data["artist"] == "J Balvin")]
non_us_df['total streams'].sum()

#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United states'],
                          'Total Countries':countries_count})
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)
plt.show()

# %%
us = chart_data[(chart_data["region"] == "United States") & (chart_data["artist"] == "Ariana Grande")]
us['total streams'].sum()
non_us_df = chart_data[(chart_data["region"] != "Global") & 
                       (chart_data["artist"] == "Ariana Grande")]
non_us_df['total streams'].sum()

#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United States'],
                          'Total Countries':countries_count})
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)
plt.show()

# %%
us = chart_data[(chart_data["region"] == "United States") & (chart_data["artist"] == "The Weeknd")]
us['total streams'].sum()
non_us_df = chart_data[(chart_data["region"] != "Global") & 
                       (chart_data["artist"] == "The Weeknd")]
non_us_df['total streams'].sum()

#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United States'],
                          'Total Countries':countries_count})
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)
plt.show()

# %%
us = chart_data[(chart_data["region"] == "United States") & (chart_data["artist"] == "Juice WRLD")]
us['total streams'].sum()
non_us_df = chart_data[(chart_data["region"] != "Global") & 
                       (chart_data["artist"] == "Juice WRLD")]
non_us_df['total streams'].sum()

#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United States'],
                          'Total Countries':countries_count})
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
# create df for all songs from 2017
df_2017_all = artists_expanded_df[(artists_expanded_df["date"] == 2017)]

# sort df by total streams to find top streams
top_artist_2017 = df_2017_all.sort_values('total streams', ascending = False)

# Find top artists by sum of streams
top_artist_2017.groupby(top_artist_2017['artist'])
sum_2017 = top_artist_2017["total streams"].groupby(top_artist_2017["artist"]).sum()
stat_2017 = pd.DataFrame({"Total streams":sum_2017})
sorted_2017 = stat_2017.sort_values("Total streams", ascending = False)

# Find the top 10 and graph it
top_2017 = sorted_2017.head(10)
top_2017_bar = top_2017.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

# adds title to bar chart  
plt.title("Top Artists 2017 by Streams")

# label xaxis
plt.xlabel("Artist")

# lable yaxis
plt.ylabel("Streams (in billions)")

# rotate xticks to fit lables
plt.xticks(rotation = 45)

# show graph 
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
#create df for all songs from 2017 and US
df_2017_all = artists_expanded_df[(artists_expanded_df["date"] == 2017) & (artists_expanded_df["region"] == "United States")]

#sort df by total streams to find most streamed
top_artist_2017 = df_2017_all.sort_values('total streams', ascending = False)

# Find top artists in US
top_artist_2017.groupby(top_artist_2017['artist'])
sum_2017 = top_artist_2017["total streams"].groupby(top_artist_2017["artist"]).sum()
stat_2017 = pd.DataFrame({"Total streams":sum_2017})
sorted_2017 = stat_2017.sort_values("Total streams", ascending = False)

# Get top 10 artists and graph
top_2017 = sorted_2017.head(10)
US_2017_bar = top_2017.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Top US Artists 2017 by Streams")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
#create df for all songs from 2018
df_2018_all = artists_expanded_df[(artists_expanded_df["date"] == 2018)]

#sort df by total streams to find top ten
top_artist_2018 = df_2018_all.sort_values('total streams', ascending = False)

top_artist_2018.groupby(top_artist_2018['artist'])
sum_2018 = top_artist_2018["total streams"].groupby(top_artist_2018["artist"]).sum()
stat_2018 = pd.DataFrame({"Total streams":sum_2018})
sorted_2018 = stat_2018.sort_values("Total streams", ascending = False)

top_2018 = sorted_2018.head(10)
top_2018_bar = top_2018.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Top Artists 2018 by Streams")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
#create df for all songs from 2018
df_2018_all = artists_expanded_df[(artists_expanded_df["date"] == 2018) & (artists_expanded_df["region"] == "United States")]

#sort df by total streams
top_artist_2018 = df_2018_all.sort_values('total streams', ascending = False)

#Find top artist in US by streams
top_artist_2018.groupby(top_artist_2018['artist'])
sum_2018 = top_artist_2018["total streams"].groupby(top_artist_2018["artist"]).sum()
stat_2018 = pd.DataFrame({"Total streams":sum_2018})
sorted_2018 = stat_2018.sort_values("Total streams", ascending = False)

#Find the top 10 and graph
top_2018 = sorted_2018.head(10)
US_2018_bar = top_2018.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Top US Artists 2018 by Streams")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
#create df for all songs from 2019
df_2019_all = artists_expanded_df[(artists_expanded_df["date"] == 2019)]

#sort df by total streams
top_artist_2019 = df_2019_all.sort_values('total streams', ascending = False)

#Find top artists by streams
top_artist_2019.groupby(top_artist_2019['artist'])
sum_2019 = top_artist_2019["total streams"].groupby(top_artist_2019["artist"]).sum()
stat_2019 = pd.DataFrame({"Total streams":sum_2019})
sorted_2019 = stat_2019.sort_values("Total streams", ascending = False)

#Find top 10 artists and graph
top_2019 = sorted_2019.head(10)
top_2019_bar = top_2019.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Top Artists 2019 by Streams")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
#create df for all songs from 2019
df_2019_all = artists_expanded_df[(artists_expanded_df["date"] == 2019) & (artists_expanded_df["region"] == "United States")]

#sort df by total streams
top_artist_2019 = df_2019_all.sort_values('total streams', ascending = False)

# Find top artists in the US
top_artist_2019.groupby(top_artist_2019['artist'])
sum_2019 = top_artist_2019["total streams"].groupby(top_artist_2019["artist"]).sum()
stat_2019 = pd.DataFrame({"Total streams":sum_2019})
sorted_2019 = stat_2019.sort_values("Total streams", ascending = False)

#Find top 10 and graph
top_2019 = sorted_2019.head(10)
top_2019_bar = top_2019.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Top US Artists 2019 by Streams")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
#create df for all songs from 2020
df_2020_all = artists_expanded_df[(artists_expanded_df["date"] == 2020)]

#sort df by total streams
top_artist_2020 = df_2020_all.sort_values('total streams', ascending = False)

#find top artists
top_artist_2020.groupby(top_artist_2020['artist'])
sum_2020 = top_artist_2020["total streams"].groupby(top_artist_2020["artist"]).sum()
stat_2020 = pd.DataFrame({"Total streams":sum_2020})
sorted_2020 = stat_2020.sort_values("Total streams", ascending = False)

#find top 10 artists and graph
top_2020 = sorted_2020.head(10)
top_2020_bar = top_2020.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Top Artists 2020 by Streams")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
#create df for all songs from 2020
df_2020_all = artists_expanded_df[(artists_expanded_df["date"] == 2020) & (artists_expanded_df["region"] == "United States")]

#sort df by total streams
top_artist_2020 = df_2020_all.sort_values('total streams', ascending = False)

#Find top artists
top_artist_2020.groupby(top_artist_2020['artist'])
sum_2020 = top_artist_2020["total streams"].groupby(top_artist_2020["artist"]).sum()
stat_2020 = pd.DataFrame({"Total streams":sum_2020})
sorted_2020 = stat_2020.sort_values("Total streams", ascending = False)

#Find top 10 and graph
top_2020 = sorted_2020.head(10)
top_2020_bar = top_2020.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Top US Artists 2020 by Streams")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
#create df for all songs from 2021
df_2021_all = artists_expanded_df[(artists_expanded_df["date"] == 2021)]

#sort df by total streams to find top ten
top_artist_2021 = df_2021_all.sort_values('total streams', ascending = False)

# find top artists
top_artist_2021.groupby(top_artist_2021['artist'])
sum_2021 = top_artist_2021["total streams"].groupby(top_artist_2021["artist"]).sum()
stat_2021 = pd.DataFrame({"Total streams":sum_2021})
sorted_2021 = stat_2021.sort_values("Total streams", ascending = False)

#Find top 10 and graph
top_2021 = sorted_2021.head(10)
top_2021_bar = top_2021.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Top Artists 2021 by Streams")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()

# %%
artists_expanded_df = regional_df.assign(artist=regional_df.artist.str.split(',')).explode('artist')
#create df for all songs from 2021
df_2021_all = artists_expanded_df[(artists_expanded_df["date"] == 2021) & (artists_expanded_df["region"] == "United States")]

#sort df by total streams
top_artist_2021 = df_2021_all.sort_values('total streams', ascending = False)

#Find top artists
top_artist_2021.groupby(top_artist_2021['artist'])
sum_2021 = top_artist_2021["total streams"].groupby(top_artist_2021["artist"]).sum()
stat_2021 = pd.DataFrame({"Total streams":sum_2021})
sorted_2021 = stat_2021.sort_values("Total streams", ascending = False)

#Find top 10 and graph
top_2021 = sorted_2021.head(10)
top_2021_bar = top_2021.plot.bar(y='Total streams', figsize =(10,10), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Top US Artists 2021 by Streams")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 45)

#show graph 
plt.show()
